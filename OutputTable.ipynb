# %% [markdown]
# | Attempt | Model    | Hyperparameters                                                                                           | Train set F1-score | Kaggle score | Sampling                  |
# |---------|----------|-----------------------------------------------------------------------------------------------------------|--------------------|--------------|---------------------------|
# | 1       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}`                                     | 0.7329             | 0.02985      | Random Undersampling      |
# | 1       | LR       | `{'C': 0.1, 'class_weight': None, 'penalty': 'l2', 'solver': 'newton-cg'}`                              | 0.7972             | 0.04449      | Random Undersampling      |
# | 1       | SVC      | `{'C': 1.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}`                                             | 0.7897             | 0.02853      | Random Undersampling      |
# | 1       | DT       | `{'criterion': 'log_loss', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 40, 'min_samples_split': 3}` | 0.7866             | 0.04493      | Random Undersampling      |
# | 1       | RF       | `{'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50}` | 0.7961             | 0.05213      | Random Undersampling      |
# | 1       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}` | 0.7959             | 0.06674      | Random Undersampling      |
# | 2       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}`                                     | 0.7803             | 0.05711      | No sampling               |
# | 2       | LR       | `{'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}`                                                     | 0.7952             | 0.05298      | No sampling               |
# | 2       | SVC      | `{'C': 0.01, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}`                                         | 0.7928             | 0.05128      | No sampling               |
# | 2       | DT       | `{'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt'}`                                         | 0.7825             | 0.05370      | No sampling               |
# | 2       | RF       | `{'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.7940             | 0.05144      | No sampling               |
# | 2       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.7896             | 0.06513      | No sampling               |
# | 3       | KNN      | `{'algorithm': 'brute', 'n_neighbors': 1, 'weights': 'uniform'}`                                         | 0.0463             | 0.03571      | SMOTE                     |
# | 3       | LR       | `{'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.0000             | 0.00000      | SMOTE                     |
# | 3       | SVC      | `{'C': 0.001, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}`                                         | 0.0000             | 0.00000      | SMOTE                     |
# | 3       | DT       | `{'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2'}`                                         | 0.0316             | 0.05555      | SMOTE                     |
# | 3       | RF       | `{'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}`     | 0.0000             | 0.00000      | SMOTE                     |
# | 3       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.0418             | 0.00000      | SMOTE                     |
# | 4       | KNN      | `{'algorithm': 'brute', 'n_neighbors': 3, 'weights': 'uniform'}`                                         | 0.8881             | 0.04739      | Random Undersampling      |
# | 4       | LR       | `{'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.7961             | 0.05144      | Random Undersampling      |
# | 4       | SVC      | `{'C': 1.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}`                                             | 0.7966             | 0.05228      | Random Undersampling      |
# | 4       | DT       | `{'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2'}`                                        | 0.8413             | 0.03601      | Random Undersampling      |
# | 4       | RF       | `{'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}`  | 0.8698             | 0.04440      | Random Undersampling      |
# | 4       | GB       | `{'criterion': 'squared_error', 'loss': 'log_loss', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}` | 0.9123             | 0.03967      | Random Undersampling      |
# | 5       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'uniform'}`                                     | 0.7871             | 0.05255      | No sampling               |
# | 5       | LR       | `{'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.8086             | 0.05132      | No sampling               |
# | 5       | SVC      | `{'C': 0.01, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}`                                         | 0.8108             | 0.05000      | No sampling               |
# | 5       | DT       | `{'criterion': 'log_loss', 'max_depth': 5, 'max_features': 'log2'}`                                      | 0.7980             | 0.06534      | No sampling               |
# | 5       | RF       | `{'bootstrap': True, 'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'n_estimators': 50}` | 0.8126             | 0.05243      | No sampling               |
# | 5       | GB       | `{'criterion': 'squared_error', 'loss': 'log_loss', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.8122             | 0.05313      | No sampling               |
# | 6       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'uniform'}`                                     | 0.0341             | 0.03571      | SMOTE                     |
# | 6       | LR       | `{'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.0000             | 0.00000      | SMOTE                     |
# | 6       | SVC      | `{'C': 0.001, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}`                                         | 0.0000             | 0.00000      | SMOTE                     |
# | 6       | DT       | `{'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2'}`                                         | 0.0283             | 0.00000      | SMOTE                     |
# | 6       | RF       | `{'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.0042             | 0.00000      | SMOTE                     |
# | 6       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.0374             | 0.07594      | SMOTE                     |
# | 7       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 3, 'weights': 'uniform'}`                                     | 0.8953             | 0.04258      | No sampling               |
# | 7       | LR       | `{'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.7975             | 0.05147      | No sampling               |
# | 7       | SVC      | `{'C': 1.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}`                                             | 0.7981             | 0.05230      | No sampling               |
# | 7       | DT       | `{'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2'}`                                        | 0.8416             | 0.04388      | No sampling               |
# | 7       | RF       | `{'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}` | 0.8718             | 0.04421      | No sampling               |
# | 7       | GB       | `{'criterion': 'squared_error', 'loss': 'log_loss', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}` | 0.9165             | 0.03919      | No sampling               |
# | 8       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'uniform'}`                                     | 0.7812             | 0.05231      | Random Undersampling      |
# | 8       | LR       | `{'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear'}`                                                 | 0.7991             | 0.05364      | Random Undersampling      |
# | 8       | SVC      | `{'C': 1.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}`                                             | 0.7996             | 0.05359      | Random Undersampling      |
# | 8       | DT       | `{'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2'}`                                         | 0.7755             | 0.04917      | Random Undersampling      |
# | 8       | RF       | `{'bootstrap': True, 'criterion': 'log_loss', 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 50}` | 0.8079             | 0.05100      | Random Undersampling      |
# | 8       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.7987             | 0.05503      | Random Undersampling      |
# | 8       | XGB      | `{'gamma': 3, 'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50, 'objective': 'binary:logistic'}` | 0.8040             | 0.05494      | Random Undersampling      |
# | 8       | VC_Hard  | `-`                                                                                                       | 0.8014             | 0.05263      | Random Undersampling      |
# | 8       | VC_Soft  | `-`                                                                                                       | 0.8008             | 0.05365      | Random Undersampling      |
# | 9       | KNN      | `{'algorithm': 'ball_tree', 'n_neighbors': 1, 'weights': 'uniform'}`                                     | 0.3694             | 0.11981      | Instant Hardness Threshold |
# | 9       | LR       | `{'C': 0.001, 'penalty': None, 'solver': 'newton-cholesky'}`                                           | 0.1257             | 0.00000      | Instant Hardness Threshold |
# | 9       | SVC      | `{'C': 0.1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}`                                            | 0.1071             | 0.02898      | Instant Hardness Threshold |
# | 9       | DT       | `{'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2'}`                                      | 0.3105             | 0.12403      | Instant Hardness Threshold |
# | 9       | RF       | `{'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 50}` | 0.3028             | 0.11009      | Instant Hardness Threshold |
# | 9       | GB       | `{'criterion': 'friedman_mse', 'loss': 'log_loss', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}` | 0.3608             | 0.11976      | Instant Hardness Threshold |
# | 9       | XGB      | `{'gamma': 0, 'learning_rate': 1.0, 'max_depth': 9, 'n_estimators': 50, 'objective': 'binary:logistic'}` | 0.3668             | 0.10370      | Instant Hardness Threshold |
# | 9       | VC_Hard  | `-`                                                                                                       | 0.2684             | 0.05940      | Instant Hardness Threshold |
# | 9       | VC_Soft  | `-`                                                                                                       | 0.2912             | 0.08080      | Instant Hardness Threshold |
# | 10      | KNN      | `{'n_neighbors': 1, 'p': 2}`                                                                             | 0.3934             | 0.12871      | Instant Hardness Threshold |
# | 10      | LR       | `{'C': 1.0, 'max_iter': 100}`                                                                             | 0.1297             | 0.00000      | Instant Hardness Threshold |
# | 10      | SVC      | `{'C': 0.1, 'gamma': 2, 'kernel': 'rbf', 'max_iter': 400}`                                              | 0.3000             | 0.04347      | Instant Hardness Threshold |
# | 10      | DT       | `{'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}`                    | 0.3022             | 0.07352      | Instant Hardness Threshold |
# | 10      | RF       | `{'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}` | 0.2971             | 0.12631      | Instant Hardness Threshold |
# | 10      | GB       | `{'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 100}`                    | 0.3942             | 0.16438      | Instant Hardness Threshold |
# | 10      | XGB      | `{'gamma': 0, 'learning_rate': 1.0, 'max_depth': 5, 'n_estimators': 100}`                                 | 0.3465             | 0.11290      | Instant Hardness Threshold |
# | 10      | VC_Hard  | `-`                                                                                                       | 0.3105             | 0.08080      | Instant Hardness Threshold |
# | 10      | VC_Soft  | `-`                                                                                                       | 0.3898             | 0.16176      | Instant Hardness Threshold |
# | 11      | KNN      | `{'n_neighbors': 1, 'p': 3}`                                                                             | 0.3663             | 0.11483      | Instant Hardness Threshold |
# | 11      | LR       | `{'C': 1.0, 'max_iter': 50}`                                                                              | 0.1236             | 0.00000      | Instant Hardness Threshold |
# | 11      | SVC      | `{'C': 0.1, 'gamma': 3, 'kernel': 'rbf'}`                                                               | 0.2749             | 0.12371      | Instant Hardness Threshold |
# | 11      | DT       | `{'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 9}`                                       | 0.3094             | 0.09756      | Instant Hardness Threshold |
# | 11      | RF       | `{'max_depth': 13, 'min_samples_leaf': 3, 'min_samples_split': 4}`                                       | 0.2505             | 0.09090      | Instant Hardness Threshold |
# | 11      | GB       | `{'max_depth': 13, 'min_samples_leaf': 5, 'min_samples_split': 5}`                                       | 0.4049             | 0.15384      | Instant Hardness Threshold |
# | 11      | XGB      | `{'gamma': 0, 'learning_rate': 1.0, 'max_depth': 4}`                                                     | 0.3590             | 0.10526      | Instant Hardness Threshold |
# | 11      | VC_Hard  | `-`                                                                                                       | 0.2925             | 0.08888      | Instant Hardness Threshold |
# | 11      | VC_Soft  | `-`                                                                                                       | 0.3895             | 0.10606      | Instant Hardness Threshold |
